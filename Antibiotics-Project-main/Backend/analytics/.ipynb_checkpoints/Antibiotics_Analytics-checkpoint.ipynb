# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_excel("ENTEROBACTER - blida.xlsx")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 563 entries, 0 to 562
# Data columns (total 20 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   souche                                537 non-null    object
#  1   SEXE                                  537 non-null    object
#  2   age                                   533 non-null    object
#  3   désignation                           537 non-null    object
#  4   date                                  537 non-null    datetime64[ns]
#  5   ATB                                   0 non-null      float64
#  6   AMPICILLINE (AMP)                     537 non-null    object
#  7   AMOXYCILLINE+ AC CLAVULANIQUE (AMC)   537 non-null    object
#  8   CEFAZOLINE (CZ)                       537 non-null    object
#  9   CEFOXITINE                            536 non-null    object
#  10  CEFOTAXIME (CTX)                      537 non-null    object
#  11  IMIPENEME (IPM)                       563 non-null    object
#  12  GENTAMICINE (GM)                      537 non-null    object
#  13  AMIKACINE (AK)                        563 non-null    object
#  14  CIPROFLOXACINE (CIP)                  537 non-null    object
#  15  FURANES (                             534 non-null    object
#  16  FOSFOMYCINE (FOS)                     535 non-null    object
#  17  TRIMETHOPRIME/SULFAMETHOXAZOLE (COT)  537 non-null    object
#  18  Remarques:                            0 non-null      float64
#  19  Unnamed: 19                           27 non-null     object
# dtypes: datetime64[ns](1), float64(2), object(17)
# memory usage: 88.1+ KB

# %%
df.head()
# Out:
#               souche SEXE age désignation       date  ATB AMPICILLINE (AMP)  \
# 0   Escherichia coli    F  35     E.C.B.U 2023-01-01  NaN                 R
# 1   Escherichia coli    F  86     E.C.B.U 2023-01-01  NaN                 R
# 2    Enterobacter sp    F  86     E.C.B.U 2023-01-01  NaN                 R
# 3  Proteus mirabilis    M   1     E.C.B.U 2023-01-01  NaN                 R
# 4   Escherichia coli    F  29     E.C.B.U 2023-01-01  NaN                 R
#
#   AMOXYCILLINE+ AC CLAVULANIQUE (AMC) CEFAZOLINE (CZ) CEFOXITINE  \
# 0                                   R               S          S
# 1                                   I               S          S
# 2                                   R               R          R
# 3                                   R               S          S
# 4                                   I               S          S
#
#   CEFOTAXIME (CTX) IMIPENEME (IPM) GENTAMICINE (GM) AMIKACINE (AK)  \
# 0                S               /                S              /
# 1                S               S                S              S
# 2                R               I                S              S
# 3                S               /                S              /
# 4                S               /                S              /
#
#   CIPROFLOXACINE (CIP) FURANES ( FOSFOMYCINE (FOS)  \
# 0                    R         S                 S
# 1                    I         S                 R
# 2                    S         S                 R
# 3                    S         R                 R
# 4                    S         S                 S
#
#   TRIMETHOPRIME/SULFAMETHOXAZOLE (COT)  Remarques: Unnamed: 19
# 0                                    S         NaN         NaN
# 1                                    R         NaN         NaN
# 2                                    S         NaN         NaN
# 3                                    S         NaN         NaN
# 4                                    I         NaN         NaN

# %%
df["labortary"] = "Blida_hygene"
df.loc[:5,"labortary"] = "Blida_Aroua"

# %%
df.head(10)
# Out:
#                   souche SEXE age désignation       date  ATB  \
# 0       Escherichia coli    F  35     E.C.B.U 2023-01-01  NaN
# 1       Escherichia coli    F  86     E.C.B.U 2023-01-01  NaN
# 2        Enterobacter sp    F  86     E.C.B.U 2023-01-01  NaN
# 3      Proteus mirabilis    M   1     E.C.B.U 2023-01-01  NaN
# 4       Escherichia coli    F  29     E.C.B.U 2023-01-01  NaN
# 5       Escherichia coli    F  62     E.C.B.U 2023-01-01  NaN
# 6       Escherichia coli    F  12     E.C.B.U 2023-01-01  NaN
# 7       Escherichia coli    M  41     E.C.B.U 2023-01-01  NaN
# 8      Proteus mirabilis    F  35     E.C.B.U 2023-01-01  NaN
# 9  Klebsiella pneumoniae    F  11     E.C.B.U 2023-01-01  NaN
#
#   AMPICILLINE (AMP) AMOXYCILLINE+ AC CLAVULANIQUE (AMC) CEFAZOLINE (CZ)  \
# 0                 R                                   R               S
# 1                 R                                   I               S
# 2                 R                                   R               R
# 3                 R                                   R               S
# 4                 R                                   I               S
# 5                 R                                   R               R
# 6                 R                                   R               I
# 7                 S                                   S               S
# 8                 S                                   S               S
# 9                 R                                   S               S
#
#   CEFOXITINE  ... IMIPENEME (IPM) GENTAMICINE (GM) AMIKACINE (AK)  \
# 0          S  ...               /                S              /
# 1          S  ...               S                S              S
# 2          R  ...               I                S              S
# 3          S  ...               /                S              /
# 4          S  ...               /                S              /
# 5          S  ...               S                S              S
# 6          S  ...               /                S              /
# 7          S  ...               /                S              /
# 8          S  ...               /                R              /
# 9          S  ...               /                S              /
#
#   CIPROFLOXACINE (CIP) FURANES ( FOSFOMYCINE (FOS)  \
# 0                    R         S                 S
# 1                    I         S                 R
# 2                    S         S                 R
# 3                    S         R                 R
# 4                    S         S                 S
# 5                    R         S                 S
# 6                    S         S                 S
# 7                    S         S                 S
# 8                    S         R                 S
# 9                    S         I                 R
#
#   TRIMETHOPRIME/SULFAMETHOXAZOLE (COT) Remarques:  \
# 0                                    S        NaN
# 1                                    R        NaN
# 2                                    S        NaN
# 3                                    S        NaN
# 4                                    I        NaN
# 5                                    R        NaN
# 6                                    R        NaN
# 7                                    S        NaN
# 8                                    R        NaN
# 9                                    S        NaN
#
#                                          Unnamed: 19     labortary
# 0                                                NaN   Blida_Aroua
# 1                                                NaN   Blida_Aroua
# 2                                                NaN   Blida_Aroua
# 3                                                NaN   Blida_Aroua
# 4                                                NaN   Blida_Aroua
# 5  E. COLI BLSE + : betalactamase a spectre élarg...   Blida_Aroua
# 6                                                NaN  Blida_hygene
# 7                                                NaN  Blida_hygene
# 8                                                NaN  Blida_hygene
# 9                                                NaN  Blida_hygene
#
# [10 rows x 21 columns]

# %% [markdown]
# # Preprocessing

# %%
for i in range(len(df)):
    if(df.iloc[i,0] == "EScherichia coli"):
        df.iloc[i,0] = "Escherichia coli"

# %% [markdown]
# # Analytics

# %%
Ecoli = df[df["souche"] == "Escherichia coli"]
Ecoli["AMPICILLINE (AMP)"].value_counts()
# Out:
# R      249
# /       66
# S       45
# I       10
# R/R     10
# R/I      1
# S/R      1
# Name: AMPICILLINE (AMP), dtype: int64

# %%
len(Ecoli)
# Out:
# 382

# %%
Resistants = [x for x in list(df.columns) if '(' in x]

# %%
def Single_Barplot_resistance(bact, resistant, title):
    sns.set_style('darkgrid')
    fig, ax1 = plt.subplots(1,1, figsize=(8, 5))
    sns.barplot(ax=ax1, x= bact[resistant].value_counts().index ,y= bact[resistant].value_counts())
    ax1.set_title(title)
    ax1.set(xlabel='Behavior (Comportement)', ylabel='Density')
    for i in ax1.containers:
        ax1.bar_label(i,)
    return ax1
        
ax = Single_Barplot_resistance(Ecoli, "AMPICILLINE (AMP)", "AMPICILLINE Resistance | Ecoli")       
ax1 = Single_Barplot_resistance(Ecoli, "AMOXYCILLINE+ AC CLAVULANIQUE (AMC)", "AMC Resistance | Ecoli")

# %%
Ecoli = df[df["souche"] == "Escherichia coli"]
Enterobacter_sp = df[df["souche"] == "Enterobacter sp"]
Proteus_mirabilis = df[df["souche"] == "Proteus mirabilis"]
Klebsiella_pneumoniae = df[df["souche"] == "Klebsiella pneumoniae"]
Citrobacter_freundii = df[df["souche"] == "Citrobacter freundii"]
Proteus_spp = df[df["souche"] == "Proteus spp"]
Serratia_spp = df[df["souche"] == "Serratia spp"]
Klebsiella_spp = df[df["souche"] == "Klebsiella spp"]
Proteuse_mirabilis = df[df["souche"] == "Proteuse mirabilis"]
Klebsiella_ozaenae = df[df["souche"] == "Klebsiella ozaenae"]
Serratia_liquefaciens = df[df["souche"] == "Serratia liquefaciens"]

# %%
def bacteria_resistance_plot(Bacteria, bacteria_name, Resistants=Resistants):
    fig, axes = plt.subplots(nrows=3, ncols=4, figsize=(20, 16))
    fig.suptitle(bacteria_name + ' Resistance', fontsize = 18)

    fig.subplots_adjust(hspace=0.4)

    axes[-1, -1].remove()
    axes = axes.flatten()
    
    for ax, resistant in zip(axes.flatten(), Resistants):
        sns.barplot(ax=ax, x=Bacteria[resistant].value_counts().index, y=Bacteria[resistant].value_counts())
        ax.set_title(resistant)
        ax.set(xlabel='Behavior (Comportement)', ylabel='Density')
        ax.set_xticklabels(Bacteria[resistant].value_counts().index, rotation=0)

        for i in ax.containers:
            ax.bar_label(i)
            

    plt.savefig("Barplots_statistics/" + bacteria_name + ".png")
    
bacteria_resistance_plot(Ecoli, "Escherichia coli")
bacteria_resistance_plot(Enterobacter_sp, "Enterobacter_sp")
bacteria_resistance_plot(Proteus_mirabilis, "Proteus_mirabilis")
bacteria_resistance_plot(Klebsiella_pneumoniae, "Klebsiella_pneumoniae")
bacteria_resistance_plot(Citrobacter_freundii, "Citrobacter_freundii")
bacteria_resistance_plot(Proteus_spp, "Proteus_spp")
bacteria_resistance_plot(Serratia_spp, "Serratia_spp")
bacteria_resistance_plot(Klebsiella_spp, "Klebsiella_spp")
bacteria_resistance_plot(Proteuse_mirabilis, "Proteuse_mirabilis")
bacteria_resistance_plot(Klebsiella_ozaenae, "Klebsiella_ozaenae")
bacteria_resistance_plot(Serratia_liquefaciens, "Serratia_liquefaciens")

# %%
Ecoli[Ecoli["date"] == "2023-01"]

resistant = Resistants[0]

R_df = df[df[resistant] == "R"]
sns.lineplot(x=Ecoli["date"], y=Ecoli[resistant], hue=Ecoli["date"])


Ecoli.groupby("date")

# sns.lineplot(x=Ecoli["date"], y=Ecoli[Resistants[0]].value_counts())
# Out:
# <Axes: xlabel='date', ylabel='AMPICILLINE (AMP)'>

# %%
Ecoli.groupby("date")['AMPICILLINE (AMP)'].value_counts().reset_index(name='count')
# Out:
#          date AMPICILLINE (AMP)  count
# 0  2022-01-01                 /     24
# 1  2022-01-01                 R      1
# 2  2022-02-01                 /     19
# 3  2022-02-01                 R     10
# 4  2022-03-01                 R     20
# 5  2022-03-01                 /      3
# 6  2022-03-01                 S      2
# 7  2022-03-01                 I      1
# 8  2022-04-01                 R     23
# 9  2022-04-01                 /      1
# 10 2022-04-01                 I      1
# 11 2022-05-01                 R     22
# 12 2022-06-01                 R     20
# 13 2022-06-01               R/R      3
# 14 2022-06-01                 /      2
# 15 2022-06-01                 I      1
# 16 2022-07-01                 R     32
# 17 2022-07-01               R/R      5
# 18 2022-07-01                 /      2
# 19 2022-07-01               R/I      1
# 20 2022-08-01                 R     16
# 21 2022-08-01                 /      2
# 22 2022-08-01               R/R      2
# 23 2022-08-01                 S      2
# 24 2022-08-01               S/R      1
# 25 2022-09-01                 R     19
# 26 2022-09-01                 S      8
# 27 2022-09-01                 /      4
# 28 2022-09-01                 I      2
# 29 2022-10-01                 R     15
# 30 2022-10-01                 S      7
# 31 2022-10-01                 /      2
# 32 2022-10-01                 I      2
# 33 2022-11-01                 R     18
# 34 2022-11-01                 S      9
# 35 2022-11-01                 I      2
# 36 2022-12-01                 R     19
# 37 2022-12-01                 S      6
# 38 2022-12-01                 I      1
# 39 2023-01-01                 R     13
# 40 2023-01-01                 S      5
# 41 2023-01-01                 /      1
# 42 2023-02-01                 R     21
# 43 2023-02-01                 /      6
# 44 2023-02-01                 S      6

# %%
pivot = Ecoli.pivot_table(index='date', columns='AMPICILLINE (AMP)', aggfunc='size', fill_value=0)
pivot = pivot.reset_index()
pivot.head()
# Out:
# AMPICILLINE (AMP)       date   /  I   R  R/I  R/R  S  S/R
# 0                 2022-01-01  24  0   1    0    0  0    0
# 1                 2022-02-01  19  0  10    0    0  0    0
# 2                 2022-03-01   3  1  20    0    0  2    0
# 3                 2022-04-01   1  1  23    0    0  0    0
# 4                 2022-05-01   0  0  22    0    0  0    0

# %%
for column in pivot_df.columns[1:]:
    sns.lineplot(x='date', y=column, data=pivot_df, label=column)
    
plt.title('Resistance over time for Escherichia coli')
# Out:
# Text(0.5, 1.0, 'Resistance over time')
